# %% [markdown]
# # Draft Test Results
#
# Notebook for presenting the results from running the test results from our successful draft run.
#
#
#
# Extra notes:
# * See the code repo README for some of the pre-requisites for running the notebook.

# %%
import os
import pandas as pd
import numpy as np
import torch

import sys
sys.path.append('../')
sys.path.append('../model/sourcemodel')
import pickle


from util import AverageMeter, accuracy
from data_manager.IDC import get_dataloader


def load_data(dir):
    with open(dir, 'rb') as f:
        data = pickle.load(f)
    f.close()
    return data


def load_idc(random_state=0):
    root = './Breast_Histopathology_Images'
    path = root + '/' + 'Breast_histopathplogy_data.csv'
    bs = 32
    cur = 1
    ss = 1.0
    n_wok = 3
    n_split = 5

    dataloader = get_dataloader(root, path, bs, ss, cur, n_wok, n_split,
                                         random_state=random_state)
    train_loader, val_loader, test_loader = dataloader.get_data_loader()

    return train_loader, val_loader, test_loader


_partition_random_state = [0,1,2]
T_SIZE = 219388
#data_fractions = [400/T_SIZE, 600/T_SIZE, 800/T_SIZE] # CA
data_fractions = [4/T_SIZE, 6/T_SIZE, 8/T_SIZE]

# %%
# Loading Original Paper's results
df = pd.read_csv('./result.csv')
df
# Out:
#       Unnamed: 0        ACC     trial_id Learning Method  Training Size  \
# 0              0  81.242989  c26a5_00004      TCL (Conv)            800
# 1              1  83.187889  c26a5_00004      TCL (Conv)            800
# 2              2  83.949829  c26a5_00004      TCL (Conv)            800
# 3              3  82.303581  c26a5_00004      TCL (Conv)            800
# 4              4  83.681763  c26a5_00004      TCL (Conv)            800
# ...          ...        ...          ...             ...            ...
# 1245        1245  84.453239  c26a5_00296      TCL (Conv)            600
# 1246        1246  82.704018  c26a5_00296      TCL (Conv)            600
# 1247        1247  80.626602  c26a5_00296      TCL (Conv)            600
# 1248        1248  80.721336  c26a5_00296      TCL (Conv)            600
# 1249        1249  82.494247  c26a5_00296      TCL (Conv)            600
#
#       partition_random_state  currerent_fold  data_percentage
# 0                          0               1         0.003647
# 1                          0               1         0.003647
# 2                          0               1         0.003647
# 3                          0               1         0.003647
# 4                          0               1         0.003647
# ...                      ...             ...              ...
# 1245                       0               4         0.002735
# 1246                       0               4         0.002735
# 1247                       0               4         0.002735
# 1248                       0               4         0.002735
# 1249                       0               4         0.002735
#
# [1250 rows x 8 columns]

# %%
draft_results = pd.read_csv('./draft_results.csv').filter(items=['Unnamed: 0', 'ACC', 'trial_id', 'Learning Method', 'Training Size', 'partition_random_state', 'currerent_fold', 'data_percentage'])
draft_results
# Out:
#     Unnamed: 0      ACC              trial_id Learning Method  Training Size  \
# 0         1250  80.4166  training_dac22_00033  TCL (Conv) DLH              8
# 1         1251  75.8265  training_dac22_00015  TCL (Conv) DLH              4
# 2         1252  75.8265  training_dac22_00055  TCL (Conv) DLH              6
# 3         1253  75.8223  training_dac22_00031  TCL (Conv) DLH              6
# 4         1254  75.7442  training_dac22_00000  TCL (Conv) DLH              4
# 5         1255  74.9299  training_dac22_00047  TCL (Conv) DLH              8
# 6         1256  73.9000  training_dac22_00007  TCL (Conv) DLH              6
# 7         1257  73.9000  training_dac22_00035  TCL (Conv) DLH              8
# 8         1258  73.9000  training_dac22_00045  TCL (Conv) DLH              8
# 9         1259  73.8950  training_dac22_00026  TCL (Conv) DLH              4
# 10        1260  73.8449  training_dac22_00003  TCL (Conv) DLH              4
# 11        1261  73.8399  training_dac22_00010  TCL (Conv) DLH              8
# 12        1262  73.7637  training_dac22_00044  TCL (Conv) DLH              8
# 13        1263  72.3283  training_dac22_00048  TCL (Conv) DLH              4
# 14        1264  71.6616  training_dac22_00036  TCL (Conv) DLH              4
# 15        1265  70.9080  training_dac22_00023  TCL (Conv) DLH              8
# 16        1266  70.9080  training_dac22_00025  TCL (Conv) DLH              4
# 17        1267  70.3091  training_dac22_00005  TCL (Conv) DLH              6
# 18        1268  70.2379  training_dac22_00028  TCL (Conv) DLH              6
# 19        1269  69.6226  training_dac22_00042  TCL (Conv) DLH              6
# 20        1270  68.9792  training_dac22_00032  TCL (Conv) DLH              8
# 21        1271  68.9777  training_dac22_00049  TCL (Conv) DLH              4
# 22        1272  68.0686  training_dac22_00029  TCL (Conv) DLH              6
# 23        1273  68.0640  training_dac22_00009  TCL (Conv) DLH              8
# 24        1274  68.0268  training_dac22_00001  TCL (Conv) DLH              4
# 25        1275  68.0268  training_dac22_00014  TCL (Conv) DLH              4
# 26        1276  68.0268  training_dac22_00018  TCL (Conv) DLH              6
# 27        1277  68.0268  training_dac22_00024  TCL (Conv) DLH              4
# 28        1278  68.0268  training_dac22_00034  TCL (Conv) DLH              8
# 29        1279  68.0031  training_dac22_00041  TCL (Conv) DLH              6
# 30        1280  58.6819  training_dac22_00056  TCL (Conv) DLH              8
# 31        1281  57.4365  training_dac22_00057  TCL (Conv) DLH              8
# 32        1282  56.7013  training_dac22_00043  TCL (Conv) DLH              6
# 33        1283  55.8775  training_dac22_00013  TCL (Conv) DLH              4
# 34        1284  54.6175  training_dac22_00059  TCL (Conv) DLH              8
# 35        1285  54.3174  training_dac22_00037  TCL (Conv) DLH              4
# 36        1286  51.6442  training_dac22_00053  TCL (Conv) DLH              6
# 37        1287  49.6578  training_dac22_00006  TCL (Conv) DLH              6
# 38        1288  48.4102  training_dac22_00016  TCL (Conv) DLH              6
# 39        1289  48.2607  training_dac22_00039  TCL (Conv) DLH              4
# 40        1290  43.8589  training_dac22_00052  TCL (Conv) DLH              6
# 41        1291  40.9967  training_dac22_00022  TCL (Conv) DLH              8
# 42        1292  40.2249  training_dac22_00038  TCL (Conv) DLH              4
# 43        1293  37.9532  training_dac22_00008  TCL (Conv) DLH              8
# 44        1294  35.0688  training_dac22_00021  TCL (Conv) DLH              8
# 45        1295  34.8423  training_dac22_00046  TCL (Conv) DLH              8
# 46        1296  34.8259  training_dac22_00017  TCL (Conv) DLH              6
# 47        1297  30.3163  training_dac22_00054  TCL (Conv) DLH              6
# 48        1298  29.3463  training_dac22_00051  TCL (Conv) DLH              4
# 49        1299  29.1587  training_dac22_00058  TCL (Conv) DLH              8
# 50        1300  29.1378  training_dac22_00050  TCL (Conv) DLH              4
# 51        1301  29.0934  training_dac22_00030  TCL (Conv) DLH              6
# 52        1302  29.0920  training_dac22_00002  TCL (Conv) DLH              4
# 53        1303  25.6421  training_dac22_00040  TCL (Conv) DLH              6
# 54        1304  24.6750  training_dac22_00020  TCL (Conv) DLH              8
# 55        1305  24.2705  training_dac22_00011  TCL (Conv) DLH              8
# 56        1306  24.1756  training_dac22_00027  TCL (Conv) DLH              4
# 57        1307  24.1735  training_dac22_00004  TCL (Conv) DLH              6
# 58        1308  24.1735  training_dac22_00012  TCL (Conv) DLH              4
# 59        1309  24.1735  training_dac22_00019  TCL (Conv) DLH              6
#
#     partition_random_state  currerent_fold  data_percentage
# 0                        2               2         0.000036
# 1                        0               3         0.000018
# 2                        2               3         0.000027
# 3                        0               3         0.000027
# 4                        1               0         0.000018
# 5                        0               2         0.000036
# 6                        0               2         0.000027
# 7                        0               2         0.000036
# 8                        0               2         0.000036
# 9                        2               2         0.000018
# 10                       1               2         0.000018
# 11                       0               2         0.000036
# 12                       2               3         0.000036
# 13                       2               0         0.000018
# 14                       0               2         0.000018
# 15                       2               0         0.000036
# 16                       0               0         0.000018
# 17                       2               0         0.000027
# 18                       1               1         0.000027
# 19                       1               0         0.000027
# 20                       2               1         0.000036
# 21                       1               1         0.000018
# 22                       0               1         0.000027
# 23                       2               4         0.000036
# 24                       1               4         0.000018
# 25                       2               4         0.000018
# 26                       0               4         0.000027
# 27                       0               4         0.000018
# 28                       1               4         0.000036
# 29                       1               4         0.000027
# 30                       1               3         0.000036
# 31                       0               1         0.000036
# 32                       1               3         0.000027
# 33                       0               3         0.000018
# 34                       0               3         0.000036
# 35                       0               1         0.000018
# 36                       0               2         0.000027
# 37                       2               2         0.000027
# 38                       1               0         0.000027
# 39                       2               2         0.000018
# 40                       0               2         0.000027
# 41                       1               4         0.000036
# 42                       0               0         0.000018
# 43                       0               2         0.000036
# 44                       0               2         0.000036
# 45                       0               4         0.000036
# 46                       2               0         0.000027
# 47                       2               0         0.000027
# 48                       1               0         0.000018
# 49                       2               0         0.000036
# 50                       0               0         0.000018
# 51                       0               0         0.000027
# 52                       0               0         0.000018
# 53                       0               3         0.000027
# 54                       0               3         0.000036
# 55                       0               3         0.000036
# 56                       1               3         0.000018
# 57                       1               3         0.000027
# 58                       2               3         0.000018
# 59                       1               3         0.000027

# %%
df = pd.concat([df, draft_results])

# %%
result_id_aux = []

for cfold in range(5):
    for lm in ['TE2E (Conv)', 'TCL (Conv)', 'TCL (Conv) DLH']:
        for d in df.data_percentage.unique(): # datapercentage
            try:
                r = df.loc[(df['currerent_fold'] == cfold)
                                    &(df['Learning Method'] == lm)
                           &(df['data_percentage'] == d)]
                result_id_aux.append(r['ACC'].idxmax())
            except Exception as e: 
                continue


aux = df.loc[result_id_aux].copy()

max_result = aux
max_result['Training Size'] = max_result['data_percentage'].apply(lambda x: int(T_SIZE * x))
max_result['Classifier'] = 'Aux'
max_result = max_result.replace('Aux', 'Auxiliary')

max_ = max_result.groupby(['Classifier','data_percentage'
                           , 'partition_random_state', 'Learning Method']).max()
max_
# Out:
#                                                                    Unnamed: 0  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.000018        0                      TCL (Conv) DLH         1251
#                            1                      TCL (Conv) DLH         1274
#                            2                      TCL (Conv) DLH         1259
#            0.000027        0                      TCL (Conv) DLH         1276
#                            1                      TCL (Conv) DLH         1268
#                            2                      TCL (Conv) DLH         1267
#            0.000036        2                      TCL (Conv) DLH         1273
#            0.001823        0                      TCL (Conv)             1025
#                                                   TE2E (Conv)             515
#                            1                      TCL (Conv)              238
#                                                   TE2E (Conv)             737
#                            2                      TE2E (Conv)             306
#            0.002735        0                      TCL (Conv)             1114
#                                                   TE2E (Conv)             268
#                            1                      TCL (Conv)              540
#                                                   TE2E (Conv)            1003
#                            2                      TE2E (Conv)            1072
#            0.003647        0                      TCL (Conv)               84
#                                                   TE2E (Conv)             587
#                            1                      TCL (Conv)              796
#                                                   TE2E (Conv)             965
#                            2                      TE2E (Conv)             452
#
#                                                                          ACC  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.000018        0                      TCL (Conv) DLH   75.826500
#                            1                      TCL (Conv) DLH   75.744200
#                            2                      TCL (Conv) DLH   73.895000
#            0.000027        0                      TCL (Conv) DLH   73.900000
#                            1                      TCL (Conv) DLH   70.237900
#                            2                      TCL (Conv) DLH   75.826500
#            0.000036        2                      TCL (Conv) DLH   80.416600
#            0.001823        0                      TCL (Conv)       85.948631
#                                                   TE2E (Conv)      83.613914
#                            1                      TCL (Conv)       84.513420
#                                                   TE2E (Conv)      85.783867
#                            2                      TE2E (Conv)      86.184517
#            0.002735        0                      TCL (Conv)       85.833664
#                                                   TE2E (Conv)      85.277023
#                            1                      TCL (Conv)       86.035881
#                                                   TE2E (Conv)      86.654587
#                            2                      TE2E (Conv)      86.390450
#            0.003647        0                      TCL (Conv)       86.413368
#                                                   TE2E (Conv)      85.410744
#                            1                      TCL (Conv)       86.699615
#                                                   TE2E (Conv)      83.567688
#                            2                      TE2E (Conv)      86.191109
#
#                                                                                trial_id  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.000018        0                      TCL (Conv) DLH   training_dac22_00015
#                            1                      TCL (Conv) DLH   training_dac22_00049
#                            2                      TCL (Conv) DLH   training_dac22_00026
#            0.000027        0                      TCL (Conv) DLH   training_dac22_00018
#                            1                      TCL (Conv) DLH   training_dac22_00028
#                            2                      TCL (Conv) DLH   training_dac22_00055
#            0.000036        2                      TCL (Conv) DLH   training_dac22_00044
#            0.001823        0                      TCL (Conv)                c26a5_00144
#                                                   TE2E (Conv)               c26a5_00295
#                            1                      TCL (Conv)                c26a5_00240
#                                                   TE2E (Conv)               c26a5_00067
#                            2                      TE2E (Conv)               c26a5_00223
#            0.002735        0                      TCL (Conv)                c26a5_00296
#                                                   TE2E (Conv)               c26a5_00105
#                            1                      TCL (Conv)                c26a5_00278
#                                                   TE2E (Conv)               c26a5_00225
#                            2                      TE2E (Conv)               c26a5_00039
#            0.003647        0                      TCL (Conv)                c26a5_00004
#                                                   TE2E (Conv)               c26a5_00059
#                            1                      TCL (Conv)                c26a5_00286
#                                                   TE2E (Conv)               c26a5_00107
#                            2                      TE2E (Conv)               c26a5_00233
#
#                                                                    Training Size  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.000018        0                      TCL (Conv) DLH               3
#                            1                      TCL (Conv) DLH               3
#                            2                      TCL (Conv) DLH               3
#            0.000027        0                      TCL (Conv) DLH               5
#                            1                      TCL (Conv) DLH               5
#                            2                      TCL (Conv) DLH               5
#            0.000036        2                      TCL (Conv) DLH               8
#            0.001823        0                      TCL (Conv)                 399
#                                                   TE2E (Conv)                399
#                            1                      TCL (Conv)                 399
#                                                   TE2E (Conv)                399
#                            2                      TE2E (Conv)                399
#            0.002735        0                      TCL (Conv)                 599
#                                                   TE2E (Conv)                599
#                            1                      TCL (Conv)                 599
#                                                   TE2E (Conv)                599
#                            2                      TE2E (Conv)                599
#            0.003647        0                      TCL (Conv)                 799
#                                                   TE2E (Conv)                799
#                            1                      TCL (Conv)                 799
#                                                   TE2E (Conv)                799
#                            2                      TE2E (Conv)                799
#
#                                                                    currerent_fold
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.000018        0                      TCL (Conv) DLH                3
#                            1                      TCL (Conv) DLH                4
#                            2                      TCL (Conv) DLH                2
#            0.000027        0                      TCL (Conv) DLH                4
#                            1                      TCL (Conv) DLH                1
#                            2                      TCL (Conv) DLH                3
#            0.000036        2                      TCL (Conv) DLH                4
#            0.001823        0                      TCL (Conv)                    1
#                                                   TE2E (Conv)                   3
#                            1                      TCL (Conv)                    3
#                                                   TE2E (Conv)                   0
#                            2                      TE2E (Conv)                   2
#            0.002735        0                      TCL (Conv)                    4
#                                                   TE2E (Conv)                   1
#                            1                      TCL (Conv)                    0
#                                                   TE2E (Conv)                   0
#                            2                      TE2E (Conv)                   2
#            0.003647        0                      TCL (Conv)                    1
#                                                   TE2E (Conv)                   4
#                            1                      TCL (Conv)                    2
#                                                   TE2E (Conv)                   3
#                            2                      TE2E (Conv)                   2

# %%
max_.trial_id
# Out:
# Classifier  data_percentage  partition_random_state  Learning Method
# Auxiliary   0.000018         0                       TCL (Conv) DLH     training_dac22_00015
#                              1                       TCL (Conv) DLH     training_dac22_00049
#                              2                       TCL (Conv) DLH     training_dac22_00026
#             0.000027         0                       TCL (Conv) DLH     training_dac22_00018
#                              1                       TCL (Conv) DLH     training_dac22_00028
#                              2                       TCL (Conv) DLH     training_dac22_00055
#             0.000036         2                       TCL (Conv) DLH     training_dac22_00044
#             0.001823         0                       TCL (Conv)                  c26a5_00144
#                                                      TE2E (Conv)                 c26a5_00295
#                              1                       TCL (Conv)                  c26a5_00240
#                                                      TE2E (Conv)                 c26a5_00067
#                              2                       TE2E (Conv)                 c26a5_00223
#             0.002735         0                       TCL (Conv)                  c26a5_00296
#                                                      TE2E (Conv)                 c26a5_00105
#                              1                       TCL (Conv)                  c26a5_00278
#                                                      TE2E (Conv)                 c26a5_00225
#                              2                       TE2E (Conv)                 c26a5_00039
#             0.003647         0                       TCL (Conv)                  c26a5_00004
#                                                      TE2E (Conv)                 c26a5_00059
#                              1                       TCL (Conv)                  c26a5_00286
#                                                      TE2E (Conv)                 c26a5_00107
#                              2                       TE2E (Conv)                 c26a5_00233
# Name: trial_id, dtype: object

# %%
# getting test result
from sklearn.metrics import confusion_matrix

paths = ['./TCL_IDC', './draft_test_results']
def get_model_score(trial_id):
    output, logit, score = 0, 0, 0
    for path in paths:
        for i in os.listdir(path):
            if trial_id in i:
                ckpt = os.path.join(path, i, 'checkpoint')
                output = torch.load(ckpt, map_location='cpu')['model_state_dict']
                logit = torch.load(ckpt, map_location='cpu')['predict_logit']
                score = torch.load(ckpt, map_location='cpu')['score']
                return output, logit, score

    return output, logit, score

def get_test_acc_logit(df, trial_id):
    trial_config = df.loc[df.trial_id == trial_id].iloc[0]
    
    _, logit, score = get_model_score(trial_id)
    return {'logit':logit, 'ACC':score}

# %%
# compute combined classifier performance

acc_combined = []
classifier = []
data_fraction = []
test_partition = []

for i in ['Auxiliary']:
    for j in df.data_percentage.unique():
        for p in df.partition_random_state.unique(): # random state of test partition
            try:
                trials = max_.loc[(i,j,p)]
                assert len(trials) == 2 # need TCL and TE2E to combine
            except:
                continue
                
            # load testing set
            test_loader = load_idc(random_state=p)[2]
            label_test = test_loader.dataset.df_data.target.to_numpy()

            trial_id = list(trials.trial_id)
            trial_1 = get_test_acc_logit(df, trial_id[0])
            trial_2 = get_test_acc_logit(df, trial_id[1])

            # result for trial 1
            logit_trial_1 = trial_1['logit']

            # result for trial 2
            logit_trial_2 = trial_2['logit']

            # combined activations
            combined = (logit_trial_1 + logit_trial_2) / 2

            # calculate acc
            acc = 100* np.sum(np.argmax(combined, axis=1) == label_test)/len(label_test)

            # combined classfiers
            acc_combined.append(acc)
            classifier.append(i)
            data_fraction.append(j)
            test_partition = [p]
        
df_combined = pd.DataFrame({'Classifier':classifier
                            , 'data_percentage':data_fraction
                            , 'Testing_ACC':acc_combined,
                           'Testing Partition':p})
df_combined['Training Size'] = df_combined['data_percentage'].apply(lambda x: int(T_SIZE * x))
df_combined['Learning Method'] = 'Combined'
df_combined
# Out:
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
#   Classifier  data_percentage  Testing_ACC  Testing Partition  Training Size  \
# 0  Auxiliary         0.003647    85.675164                  2            799
# 1  Auxiliary         0.003647    85.765246                  2            799
# 2  Auxiliary         0.001823    84.055490                  2            399
# 3  Auxiliary         0.001823    85.386902                  2            399
# 4  Auxiliary         0.002735    85.042789                  2            599
# 5  Auxiliary         0.002735    85.844519                  2            599
#
#   Learning Method
# 0        Combined
# 1        Combined
# 2        Combined
# 3        Combined
# 4        Combined
# 5        Combined

# %%
acc = []
classifier = []
data_fraction = []
learning_method = []
test_partition = []

for i in ['Auxiliary']:
    for j in df.data_percentage.unique():
        for p in df.partition_random_state.unique(): # random state of test partition
            for l in ['TCL (Conv)', 'TE2E (Conv)', 'TCL (Conv) DLH']:
                try:
                    trials = max_.loc[(i,j,p,l)] # fetch trials from max_
                except:
                    continue
                if l in ['TCL (Conv)', 'TE2E (Conv)']:
                    trial_acc = get_test_acc_logit(df, trials.trial_id)['ACC']
                else:
                    trial_acc = df.loc[df.trial_id == trials.trial_id]['ACC'].iloc[0]
                    print(f'trial_acc: {trial_acc}')

                # combined classfiers
                acc.append(trial_acc)
                classifier.append(i)
                data_fraction.append(j)
                learning_method.append(l)
                test_partition.append(p)
        
df_new = pd.DataFrame({'Classifier':classifier
                            , 'data_percentage':data_fraction
                            , 'Testing_ACC':acc,
                      'Learning Method':learning_method, 
                      'Testing Partition':test_partition})

df_new['Training Size'] = df_new['data_percentage'].apply(lambda x: int(T_SIZE * x))
df_new
# Out:
# trial_acc: 73.7637
# trial_acc: 75.8265
# trial_acc: 68.9777
# trial_acc: 73.895
# trial_acc: 68.0268
# trial_acc: 70.2379
# trial_acc: 75.8265
#    Classifier  data_percentage  Testing_ACC Learning Method  \
# 0   Auxiliary         0.003647    84.550941      TCL (Conv)
# 1   Auxiliary         0.003647    83.949196     TE2E (Conv)
# 2   Auxiliary         0.003647    85.511215      TCL (Conv)
# 3   Auxiliary         0.003647    82.853798     TE2E (Conv)
# 4   Auxiliary         0.003647    83.469955     TE2E (Conv)
# 5   Auxiliary         0.001823    83.606880      TCL (Conv)
# 6   Auxiliary         0.001823    83.178093     TE2E (Conv)
# 7   Auxiliary         0.001823    84.922081      TCL (Conv)
# 8   Auxiliary         0.001823    83.871727     TE2E (Conv)
# 9   Auxiliary         0.001823    83.925774     TE2E (Conv)
# 10  Auxiliary         0.002735    84.356369      TCL (Conv)
# 11  Auxiliary         0.002735    83.484375     TE2E (Conv)
# 12  Auxiliary         0.002735    85.767052      TCL (Conv)
# 13  Auxiliary         0.002735    84.682465     TE2E (Conv)
# 14  Auxiliary         0.002735    83.864517     TE2E (Conv)
# 15  Auxiliary         0.000036    73.763700  TCL (Conv) DLH
# 16  Auxiliary         0.000018    75.826500  TCL (Conv) DLH
# 17  Auxiliary         0.000018    68.977700  TCL (Conv) DLH
# 18  Auxiliary         0.000018    73.895000  TCL (Conv) DLH
# 19  Auxiliary         0.000027    68.026800  TCL (Conv) DLH
# 20  Auxiliary         0.000027    70.237900  TCL (Conv) DLH
# 21  Auxiliary         0.000027    75.826500  TCL (Conv) DLH
#
#     Testing Partition  Training Size
# 0                   0            799
# 1                   0            799
# 2                   1            799
# 3                   1            799
# 4                   2            799
# 5                   0            399
# 6                   0            399
# 7                   1            399
# 8                   1            399
# 9                   2            399
# 10                  0            599
# 11                  0            599
# 12                  1            599
# 13                  1            599
# 14                  2            599
# 15                  2              8
# 16                  0              3
# 17                  1              3
# 18                  2              3
# 19                  0              5
# 20                  1              5
# 21                  2              5

# %%
max_combined = df_new.merge(df_combined, on=list(df_combined), how='outer')
max_combined = max_combined.rename(columns={'Testing_ACC': 'Testing ACC'})
max_combined
# Out:
#    Classifier  data_percentage  Testing ACC Learning Method  \
# 0   Auxiliary         0.003647    84.550941      TCL (Conv)
# 1   Auxiliary         0.003647    83.949196     TE2E (Conv)
# 2   Auxiliary         0.003647    85.511215      TCL (Conv)
# 3   Auxiliary         0.003647    82.853798     TE2E (Conv)
# 4   Auxiliary         0.003647    83.469955     TE2E (Conv)
# 5   Auxiliary         0.001823    83.606880      TCL (Conv)
# 6   Auxiliary         0.001823    83.178093     TE2E (Conv)
# 7   Auxiliary         0.001823    84.922081      TCL (Conv)
# 8   Auxiliary         0.001823    83.871727     TE2E (Conv)
# 9   Auxiliary         0.001823    83.925774     TE2E (Conv)
# 10  Auxiliary         0.002735    84.356369      TCL (Conv)
# 11  Auxiliary         0.002735    83.484375     TE2E (Conv)
# 12  Auxiliary         0.002735    85.767052      TCL (Conv)
# 13  Auxiliary         0.002735    84.682465     TE2E (Conv)
# 14  Auxiliary         0.002735    83.864517     TE2E (Conv)
# 15  Auxiliary         0.000036    73.763700  TCL (Conv) DLH
# 16  Auxiliary         0.000018    75.826500  TCL (Conv) DLH
# 17  Auxiliary         0.000018    68.977700  TCL (Conv) DLH
# 18  Auxiliary         0.000018    73.895000  TCL (Conv) DLH
# 19  Auxiliary         0.000027    68.026800  TCL (Conv) DLH
# 20  Auxiliary         0.000027    70.237900  TCL (Conv) DLH
# 21  Auxiliary         0.000027    75.826500  TCL (Conv) DLH
# 22  Auxiliary         0.003647    85.675164        Combined
# 23  Auxiliary         0.003647    85.765246        Combined
# 24  Auxiliary         0.001823    84.055490        Combined
# 25  Auxiliary         0.001823    85.386902        Combined
# 26  Auxiliary         0.002735    85.042789        Combined
# 27  Auxiliary         0.002735    85.844519        Combined
#
#     Testing Partition  Training Size
# 0                   0            799
# 1                   0            799
# 2                   1            799
# 3                   1            799
# 4                   2            799
# 5                   0            399
# 6                   0            399
# 7                   1            399
# 8                   1            399
# 9                   2            399
# 10                  0            599
# 11                  0            599
# 12                  1            599
# 13                  1            599
# 14                  2            599
# 15                  2              8
# 16                  0              3
# 17                  1              3
# 18                  2              3
# 19                  0              5
# 20                  1              5
# 21                  2              5
# 22                  2            799
# 23                  2            799
# 24                  2            399
# 25                  2            399
# 26                  2            599
# 27                  2            599

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid", font_scale=1.5)
sns.color_palette("hls")

sns.catplot(data=max_combined, x='Training Size', y='Testing ACC'
            , hue='Learning Method',col='Classifier', kind='box',
           height=6, aspect=1.0,)
