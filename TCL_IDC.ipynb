# %% [markdown]
# # More instructions for running locally
#
# https://doc.cocalc.com/howto/custom-jupyter-kernel.html
#
# #!python3.10 -m pip install --upgrade pip
# #!pip install pandas
# #!pip install "torch>=1.7.0+cpu" "torchvision>=0.8.1+cpu" -f https://download.pytorch.org/whl/torch_stable.html
# #!pip install ~/Downloads/
# #!pip install -U "ray[air]"
# #!pip install opencv-python
# #!pip install sklearn
# !pip install -U scikit-learn
# #!brew install xz
# #!pip install -r requirements.txt

# %%
#!tar -zxvf TCL_IDC.tar.gz 
#!tar -xvf TCL_IDC.tar
# Out:
# x TCL_IDC/
# x TCL_IDC/c26a5_00286/
# x TCL_IDC/c26a5_00105/
# x TCL_IDC/.DS_Store
# x TCL_IDC/c26a5_00144/
# x TCL_IDC/c26a5_00233/
# x TCL_IDC/c26a5_00039/
# x TCL_IDC/c26a5_00295/
# x TCL_IDC/c26a5_00278/
# x TCL_IDC/c26a5_00240/
# x TCL_IDC/c26a5_00225/
# x TCL_IDC/c26a5_00223/
# x TCL_IDC/c26a5_00107/
# x TCL_IDC/c26a5_00067/
# x TCL_IDC/c26a5_00004/
# x TCL_IDC/c26a5_00296/
# x TCL_IDC/c26a5_00059/
# x TCL_IDC/c26a5_00059/.DS_Store
# x TCL_IDC/c26a5_00059/checkpoint
# x TCL_IDC/c26a5_00296/.DS_Store
# x TCL_IDC/c26a5_00296/checkpoint
# x TCL_IDC/c26a5_00004/.DS_Store
# x TCL_IDC/c26a5_00004/checkpoint
# x TCL_IDC/c26a5_00067/.DS_Store
# x TCL_IDC/c26a5_00067/checkpoint
# x TCL_IDC/c26a5_00107/.DS_Store
# x TCL_IDC/c26a5_00107/checkpoint
# x TCL_IDC/c26a5_00223/.DS_Store
# x TCL_IDC/c26a5_00223/checkpoint
# x TCL_IDC/c26a5_00225/.DS_Store
# x TCL_IDC/c26a5_00225/checkpoint
# x TCL_IDC/c26a5_00240/.DS_Store
# x TCL_IDC/c26a5_00240/checkpoint
# x TCL_IDC/c26a5_00278/.DS_Store
# x TCL_IDC/c26a5_00278/checkpoint
# x TCL_IDC/c26a5_00295/.DS_Store
# x TCL_IDC/c26a5_00295/checkpoint
# x TCL_IDC/c26a5_00039/.DS_Store
# x TCL_IDC/c26a5_00039/checkpoint
# x TCL_IDC/c26a5_00233/.DS_Store
# x TCL_IDC/c26a5_00233/checkpoint
# x TCL_IDC/c26a5_00144/.DS_Store
# x TCL_IDC/c26a5_00144/checkpoint
# x TCL_IDC/c26a5_00105/.DS_Store
# x TCL_IDC/c26a5_00105/checkpoint
# x TCL_IDC/c26a5_00286/.DS_Store
# x TCL_IDC/c26a5_00286/checkpoint

# %%
# Out:
# Requirement already satisfied: pip in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (22.0.4)
# Collecting pip
#   Using cached pip-23.0.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.4
#     Uninstalling pip-22.0.4:
#       Successfully uninstalled pip-22.0.4
# Successfully installed pip-23.0.1

# %%
# Out:
# Collecting pandas
#   Downloading pandas-1.5.3-cp310-cp310-macosx_10_9_x86_64.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 15.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
# Successfully installed pandas-1.5.3
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/Users/cesar/.pyenv/versions/3.10.4/bin/python3.10 -m pip install --upgrade pip' command.

# %%
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch>=1.7.0+cpu
#   Using cached torch-1.13.1-cp310-none-macosx_10_9_x86_64.whl (135.3 MB)
# Collecting torchvision>=0.8.1+cpu
#   Using cached torchvision-0.14.1-cp310-cp310-macosx_10_9_x86_64.whl (1.4 MB)
# Requirement already satisfied: typing-extensions in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from torch>=1.7.0+cpu) (4.5.0)
# Requirement already satisfied: requests in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from torchvision>=0.8.1+cpu) (2.28.2)
# Requirement already satisfied: numpy in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from torchvision>=0.8.1+cpu) (1.24.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from torchvision>=0.8.1+cpu) (9.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from requests->torchvision>=0.8.1+cpu) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from requests->torchvision>=0.8.1+cpu) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from requests->torchvision>=0.8.1+cpu) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from requests->torchvision>=0.8.1+cpu) (2022.12.7)
# Installing collected packages: torch, torchvision
# Successfully installed torch-1.13.1 torchvision-0.14.1

# %%
# Out:
# Collecting ray[air]
#   Downloading ray-2.3.0-cp310-cp310-macosx_10_15_universal2.whl (78.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 MB 16.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /Users/cesar/.local/lib/python3.10/site-packages (from ray[air]) (3.9.0)
# Requirement already satisfied: numpy>=1.19.3 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (1.22.4)
# Requirement already satisfied: jsonschema in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (4.5.1)
# Collecting frozenlist
#   Downloading frozenlist-1.3.3-cp310-cp310-macosx_10_9_x86_64.whl (35 kB)
# Requirement already satisfied: attrs in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (21.4.0)
# Requirement already satisfied: packaging in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (21.3)
# Collecting protobuf!=3.19.5,>=3.15.3
#   Downloading protobuf-4.22.1-cp37-abi3-macosx_10_9_universal2.whl (397 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.2/397.2 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (2.27.1)
# Requirement already satisfied: virtualenv>=20.0.24 in /Users/cesar/.local/lib/python3.10/site-packages (from ray[air]) (20.17.1)
# Collecting grpcio<=1.49.1,>=1.42.0
#   Downloading grpcio-1.49.1-cp310-cp310-macosx_10_10_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 35.7 MB/s eta 0:00:0000:0100:01
# Collecting aiosignal
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting click>=7.0
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 6.5 MB/s eta 0:00:00
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 10.6 MB/s eta 0:00:00
# Collecting msgpack<2.0.0,>=1.0.0
#   Downloading msgpack-1.0.5-cp310-cp310-macosx_10_9_x86_64.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (1.5.3)
# Collecting aiohttp>=3.7
#   Downloading aiohttp-3.8.4-cp310-cp310-macosx_10_9_x86_64.whl (358 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.1/358.1 kB 4.7 MB/s eta 0:00:00a 0:00:01
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting fastapi
#   Downloading fastapi-0.93.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 3.3 MB/s eta 0:00:00
# Collecting pydantic
#   Downloading pydantic-1.10.6-cp310-cp310-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 15.8 MB/s eta 0:00:0000:0100:01
# Collecting colorful
#   Downloading colorful-0.5.5-py2.py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from ray[air]) (0.14.1)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 8.8 MB/s eta 0:00:00
# Collecting gpustat>=1.0.0
#   Downloading gpustat-1.0.0.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.5/90.5 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fsspec
#   Downloading fsspec-2023.3.0-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 6.4 MB/s eta 0:00:00
# Collecting starlette
#   Downloading starlette-0.25.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.0 MB/s eta 0:00:00
# Collecting pyarrow>=6.0.1
#   Downloading pyarrow-11.0.0-cp310-cp310-macosx_10_14_x86_64.whl (24.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.4/24.4 MB 23.5 MB/s eta 0:00:0000:0100:01
# Collecting opencensus
#   Downloading opencensus-0.11.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 9.4 MB/s eta 0:00:00
# Collecting smart-open
#   Downloading smart_open-6.3.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 5.6 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.20.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 3.8 MB/s eta 0:00:00
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting aiorwlock
#   Downloading aiorwlock-1.3.0-py3-none-any.whl (10.0 kB)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.3.14-py2.py3-none-macosx_10_9_x86_64.macosx_11_0_arm64.macosx_10_9_universal2.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 36.3 MB/s eta 0:00:0000:0100:01
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp310-cp310-macosx_10_9_x86_64.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from aiohttp>=3.7->ray[air]) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-macosx_10_9_x86_64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: six>=1.7 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[air]) (1.16.0)
# Collecting nvidia-ml-py<=11.495.46,>=11.450.129
#   Downloading nvidia_ml_py-11.495.46-py3-none-any.whl (25 kB)
# Requirement already satisfied: psutil>=5.6.0 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[air]) (5.9.0)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas>=1.3->ray[air]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pandas>=1.3->ray[air]) (2022.1)
# Collecting protobuf!=3.19.5,>=3.15.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: platformdirs<3,>=2.4 in /Users/cesar/.local/lib/python3.10/site-packages (from virtualenv>=20.0.24->ray[air]) (2.6.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/cesar/.local/lib/python3.10/site-packages (from virtualenv>=20.0.24->ray[air]) (0.3.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from pydantic->ray[air]) (4.5.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from starlette->ray[air]) (3.6.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from jsonschema->ray[air]) (0.18.1)
# Collecting google-api-core<3.0.0,>=1.0.0
#   Downloading google_api_core-2.11.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 9.1 MB/s eta 0:00:00
# Collecting opencensus-context>=0.1.3
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from packaging->ray[air]) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests->ray[air]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests->ray[air]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from requests->ray[air]) (1.26.9)
# Collecting h11>=0.8
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: sniffio>=1.1 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette->ray[air]) (1.2.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[air]) (0.2.5)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Downloading googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 7.4 MB/s eta 0:00:00
# Collecting google-auth<3.0dev,>=2.14.1
#   Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 10.4 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 13.3 MB/s eta 0:00:00
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pyasn1, py-spy, opencensus-context, nvidia-ml-py, msgpack, colorful, tabulate, smart-open, rsa, pyyaml, pydantic, pyasn1-modules, pyarrow, protobuf, multidict, h11, grpcio, fsspec, frozenlist, click, cachetools, blessed, async-timeout, aiorwlock, yarl, uvicorn, tensorboardX, starlette, gpustat, googleapis-common-protos, google-auth, aiosignal, ray, google-api-core, fastapi, aiohttp, opencensus, aiohttp-cors
#   DEPRECATION: gpustat is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for gpustat ... done
# Successfully installed aiohttp-3.8.4 aiohttp-cors-0.7.0 aiorwlock-1.3.0 aiosignal-1.3.1 async-timeout-4.0.2 blessed-1.20.0 cachetools-5.3.0 click-8.1.3 colorful-0.5.5 fastapi-0.93.0 frozenlist-1.3.3 fsspec-2023.3.0 google-api-core-2.11.0 google-auth-2.16.2 googleapis-common-protos-1.58.0 gpustat-1.0.0 grpcio-1.49.1 h11-0.14.0 msgpack-1.0.5 multidict-6.0.4 nvidia-ml-py-11.495.46 opencensus-0.11.1 opencensus-context-0.1.3 protobuf-3.20.3 py-spy-0.3.14 pyarrow-11.0.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pydantic-1.10.6 pyyaml-6.0 ray-2.3.0 rsa-4.9 smart-open-6.3.0 starlette-0.25.0 tabulate-0.9.0 tensorboardX-2.6 uvicorn-0.20.0 yarl-1.8.2

# %%
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-macosx_10_16_x86_64.whl (53.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 24.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.19.3 in /Users/cesar/.pyenv/versions/3.10.4/lib/python3.10/site-packages (from opencv-python) (1.22.4)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72

# %%
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Installing collected packages: sklearn
#   DEPRECATION: sklearn is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for sklearn ... done
# Successfully installed sklearn-0.0.post1

# %%
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-1.2.1-cp310-cp310-macosx_10_9_x86_64.whl (9.1 MB)
# Requirement already satisfied: numpy>=1.17.3 in /Users/cesar/.pyenv/versions/3.10.10/lib/python3.10/site-packages (from scikit-learn) (1.24.2)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting joblib>=1.1.1
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting scipy>=1.3.2
#   Using cached scipy-1.10.1-cp310-cp310-macosx_10_9_x86_64.whl (35.1 MB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 scipy-1.10.1 threadpoolctl-3.1.0

# %%
# Out:
# Running `brew update --auto-update`...

# %%
# Out:
# Collecting torchsummary~=1.5.1
#   Using cached torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Collecting numpy~=1.21.4
#   Using cached numpy-1.21.6-cp310-cp310-macosx_10_9_x86_64.whl (17.0 MB)
# Collecting sklearn~=0.0
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-learn~=0.24.0
#   Using cached scikit-learn-0.24.2.tar.gz (7.5 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas~=1.3.4
#   Using cached pandas-1.3.5-cp310-cp310-macosx_10_9_x86_64.whl (11.3 MB)
# Collecting pillow~=8.0.1
#   Using cached Pillow-8.0.1.tar.gz (44.6 MB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit-image~=0.18.1
#   Downloading scikit-image-0.18.3.tar.gz (29.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.2/29.2 MB 28.8 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting argparse~=1.4.0
#   Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# ERROR: Could not find a version that satisfies the requirement ray~=1.8.0 (from versions: 1.13.0, 2.0.0rc0, 2.0.0rc1, 2.0.0, 2.0.1, 2.1.0, 2.2.0, 2.3.0rc0, 2.3.0)
# ERROR: No matching distribution found for ray~=1.8.0

# %%
import os
import pandas as pd
import numpy as np
import torch

import sys
sys.path.append('../')
sys.path.append('../model/sourcemodel')
import pickle

from util import AverageMeter, accuracy

def load_data(dir):
    with open(dir, 'rb') as f:
        data = pickle.load(f)
    f.close()
    return data

_partition_random_state = [0,1,2]
T_SIZE = 219388
data_fractions = [400/T_SIZE, 600/T_SIZE, 800/T_SIZE]

# %%
# testing
def validate_aux(val_loader, model, criterion, print_freq):
    """One epoch validation for aux type classifier"""
    batch_time = AverageMeter()
    losses = AverageMeter()
    top1 = AverageMeter()

    # switch to evaluate mode
    model.eval()

    with torch.no_grad():
        labels = []
        outputs = []
        logit_out = []
        for idx, (input, target) in enumerate(val_loader):
            
            input = input.float()
            if torch.cuda.is_available():
                input = input.cuda()
                target = target.cuda()

            # compute output
            output = model(input)
            loss = criterion(output, target)

            # append result:
            labels.append(target.cpu().numpy())
            outputs.append(np.argmax(output.cpu().numpy(), axis=1))
            logit_out.append(output.cpu().numpy())

            # measure accuracy and record loss
            acc1, _ = accuracy(output, target, topk=(1, 2))

            losses.update(loss.item(), input.size(0))
            top1.update(acc1[0], input.size(0))

            if idx % print_freq == 0:
                print('Test: [{0}/{1}]\t'
                      'Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t'
                      'Loss {loss.val:.4f} ({loss.avg:.4f})\t'
                      'Acc@1 {top1.val:.3f} ({top1.avg:.3f})\t'
                    .format(
                    idx, len(val_loader), batch_time=batch_time, loss=losses,
                    top1=top1, ))

        print(' * Acc@1 {top1.avg:.3f}'
              .format(top1=top1))

        labels = np.hstack(labels)
        outputs = np.hstack(outputs)
        logit_out = np.vstack(logit_out)

    # return top1.avg, losses.avg, f1.avg, auc_meter.avg, auc_meter.cls_auc, ece.ece_, ece.acc, ece.conf
    return {'ACC': top1.avg.item(),
            'logit': logit_out,
            }

# %%
from data_manager.IDC import get_dataloader
def load_idc(random_state=0):
    root = './Breast Histopathology Images'
    path = root + '/' + 'Breast_histopathplogy_data.csv'
    bs = 32
    cur = 1
    ss = 1.0
    n_wok = 3
    n_split = 5

    dataloader = get_dataloader(root, path, bs, ss, cur, n_wok, n_split,
                                         random_state=random_state)
    train_loader, val_loader, test_loader = dataloader.get_data_loader()

    return train_loader, val_loader, test_loader

# %%
df = pd.read_csv('./result.csv')
df
# Out:
#       Unnamed: 0        ACC     trial_id Learning Method  Training Size  \
# 0              0  81.242989  c26a5_00004      TCL (Conv)            800
# 1              1  83.187889  c26a5_00004      TCL (Conv)            800
# 2              2  83.949829  c26a5_00004      TCL (Conv)            800
# 3              3  82.303581  c26a5_00004      TCL (Conv)            800
# 4              4  83.681763  c26a5_00004      TCL (Conv)            800
# ...          ...        ...          ...             ...            ...
# 1245        1245  84.453239  c26a5_00296      TCL (Conv)            600
# 1246        1246  82.704018  c26a5_00296      TCL (Conv)            600
# 1247        1247  80.626602  c26a5_00296      TCL (Conv)            600
# 1248        1248  80.721336  c26a5_00296      TCL (Conv)            600
# 1249        1249  82.494247  c26a5_00296      TCL (Conv)            600
#
#       partition_random_state  currerent_fold  data_percentage
# 0                          0               1         0.003647
# 1                          0               1         0.003647
# 2                          0               1         0.003647
# 3                          0               1         0.003647
# 4                          0               1         0.003647
# ...                      ...             ...              ...
# 1245                       0               4         0.002735
# 1246                       0               4         0.002735
# 1247                       0               4         0.002735
# 1248                       0               4         0.002735
# 1249                       0               4         0.002735
#
# [1250 rows x 8 columns]

# %%
result_id_aux = []

for cfold in range(5):
    for lm in ['TE2E (Conv)', 'TCL (Conv)']:
            for d in df.data_percentage.unique(): # datapercentage
                try:
                    r = df.loc[(df['currerent_fold'] == cfold)
                                        &(df['Learning Method'] == lm)
                               &(df['data_percentage'] == d)]
                    result_id_aux.append(r['ACC'].idxmax())
                except Exception as e: 
                    continue


aux = df.loc[result_id_aux].copy()

max_result = aux
max_result['Training Size'] = max_result['data_percentage'].apply(lambda x: int(T_SIZE * x))
max_result['Classifier'] = 'Aux'
max_result = max_result.replace('Aux', 'Auxiliary')

max_ = max_result.groupby(['Classifier','data_percentage'
                           , 'partition_random_state', 'Learning Method']).max()
max_
# Out:
#                                                                    Unnamed: 0  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.001823        0                      TCL (Conv)             1025
#                                                   TE2E (Conv)             515
#                            1                      TCL (Conv)              238
#                                                   TE2E (Conv)             737
#                            2                      TE2E (Conv)             306
#            0.002735        0                      TCL (Conv)             1114
#                                                   TE2E (Conv)             268
#                            1                      TCL (Conv)              540
#                                                   TE2E (Conv)            1003
#                            2                      TE2E (Conv)            1072
#            0.003647        0                      TCL (Conv)               84
#                                                   TE2E (Conv)             587
#                            1                      TCL (Conv)              796
#                                                   TE2E (Conv)             965
#                            2                      TE2E (Conv)             452
#
#                                                                          ACC  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.001823        0                      TCL (Conv)       85.948631
#                                                   TE2E (Conv)      83.613914
#                            1                      TCL (Conv)       84.513420
#                                                   TE2E (Conv)      85.783867
#                            2                      TE2E (Conv)      86.184517
#            0.002735        0                      TCL (Conv)       85.833664
#                                                   TE2E (Conv)      85.277023
#                            1                      TCL (Conv)       86.035881
#                                                   TE2E (Conv)      86.654587
#                            2                      TE2E (Conv)      86.390450
#            0.003647        0                      TCL (Conv)       86.413368
#                                                   TE2E (Conv)      85.410744
#                            1                      TCL (Conv)       86.699615
#                                                   TE2E (Conv)      83.567688
#                            2                      TE2E (Conv)      86.191109
#
#                                                                       trial_id  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.001823        0                      TCL (Conv)       c26a5_00144
#                                                   TE2E (Conv)      c26a5_00295
#                            1                      TCL (Conv)       c26a5_00240
#                                                   TE2E (Conv)      c26a5_00067
#                            2                      TE2E (Conv)      c26a5_00223
#            0.002735        0                      TCL (Conv)       c26a5_00296
#                                                   TE2E (Conv)      c26a5_00105
#                            1                      TCL (Conv)       c26a5_00278
#                                                   TE2E (Conv)      c26a5_00225
#                            2                      TE2E (Conv)      c26a5_00039
#            0.003647        0                      TCL (Conv)       c26a5_00004
#                                                   TE2E (Conv)      c26a5_00059
#                            1                      TCL (Conv)       c26a5_00286
#                                                   TE2E (Conv)      c26a5_00107
#                            2                      TE2E (Conv)      c26a5_00233
#
#                                                                    Training Size  \
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.001823        0                      TCL (Conv)                 399
#                                                   TE2E (Conv)                399
#                            1                      TCL (Conv)                 399
#                                                   TE2E (Conv)                399
#                            2                      TE2E (Conv)                399
#            0.002735        0                      TCL (Conv)                 599
#                                                   TE2E (Conv)                599
#                            1                      TCL (Conv)                 599
#                                                   TE2E (Conv)                599
#                            2                      TE2E (Conv)                599
#            0.003647        0                      TCL (Conv)                 799
#                                                   TE2E (Conv)                799
#                            1                      TCL (Conv)                 799
#                                                   TE2E (Conv)                799
#                            2                      TE2E (Conv)                799
#
#                                                                    currerent_fold
# Classifier data_percentage partition_random_state Learning Method
# Auxiliary  0.001823        0                      TCL (Conv)                    1
#                                                   TE2E (Conv)                   3
#                            1                      TCL (Conv)                    3
#                                                   TE2E (Conv)                   0
#                            2                      TE2E (Conv)                   2
#            0.002735        0                      TCL (Conv)                    4
#                                                   TE2E (Conv)                   1
#                            1                      TCL (Conv)                    0
#                                                   TE2E (Conv)                   0
#                            2                      TE2E (Conv)                   2
#            0.003647        0                      TCL (Conv)                    1
#                                                   TE2E (Conv)                   4
#                            1                      TCL (Conv)                    2
#                                                   TE2E (Conv)                   3
#                            2                      TE2E (Conv)                   2

# %%
max_.trial_id
# Out:
# Classifier  data_percentage  partition_random_state  Learning Method
# Auxiliary   0.001823         0                       TCL (Conv)         c26a5_00144
#                                                      TE2E (Conv)        c26a5_00295
#                              1                       TCL (Conv)         c26a5_00240
#                                                      TE2E (Conv)        c26a5_00067
#                              2                       TE2E (Conv)        c26a5_00223
#             0.002735         0                       TCL (Conv)         c26a5_00296
#                                                      TE2E (Conv)        c26a5_00105
#                              1                       TCL (Conv)         c26a5_00278
#                                                      TE2E (Conv)        c26a5_00225
#                              2                       TE2E (Conv)        c26a5_00039
#             0.003647         0                       TCL (Conv)         c26a5_00004
#                                                      TE2E (Conv)        c26a5_00059
#                              1                       TCL (Conv)         c26a5_00286
#                                                      TE2E (Conv)        c26a5_00107
#                              2                       TE2E (Conv)        c26a5_00233
# Name: trial_id, dtype: object

# %%
# getting test result
from sklearn.metrics import confusion_matrix

path = './TCL_IDC'
def get_model_score(trial_id):
    output, logit, score = 0, 0, 0
    for i in os.listdir(path):
        if trial_id in i:
            ckpt = os.path.join(path, i, 'checkpoint')
#                     print(torch.load(ckpt, map_location='cpu'))
            output = torch.load(ckpt, map_location='cpu')['model_state_dict']
            logit = torch.load(ckpt, map_location='cpu')['predict_logit']
            score = torch.load(ckpt, map_location='cpu')['score']
                        
    return output, logit, score

def get_test_acc_logit(df, trial_id):
    trial_config = df.loc[df.trial_id == trial_id].iloc[0]
    
    _, logit, score = get_model_score(trial_id)
    return {'logit':logit, 'ACC':score}

# %%
# compute combined classifier performance

acc_combined = []
classifier = []
data_fraction = []
test_partition = []

for i in ['Auxiliary']:
    for j in df.data_percentage.unique():
        for p in df.partition_random_state.unique(): # random state of test partition
            try:
                trials = max_.loc[(i,j,p)]
                assert len(trials) == 2 # need TCL and TE2E to combine
            except:
                continue
                
            # load testing set
            test_loader = load_idc(random_state=p)[2]
            label_test = test_loader.dataset.df_data.target.to_numpy()

            trial_id = list(trials.trial_id)
            trial_1 = get_test_acc_logit(df, trial_id[0])
            trial_2 = get_test_acc_logit(df, trial_id[1])

            # result for trial 1
            logit_trial_1 = trial_1['logit']

            # result for trial 2
            logit_trial_2 = trial_2['logit']

            # combined activations
            combined = (logit_trial_1 + logit_trial_2) / 2

            # calculate acc
            acc = 100* np.sum(np.argmax(combined, axis=1) == label_test)/len(label_test)

            # combined classfiers
            acc_combined.append(acc)
            classifier.append(i)
            data_fraction.append(j)
            test_partition = [p]
        
df_combined = pd.DataFrame({'Classifier':classifier
                            , 'data_percentage':data_fraction
                            , 'Testing_ACC':acc_combined,
                           'Testing Partition':p})
df_combined['Training Size'] = df_combined['data_percentage'].apply(lambda x: int(T_SIZE * x))
df_combined['Learning Method'] = 'Combined'
df_combined
# Out:
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
# 5 cross validation, patiens nums
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  223   |   test -  56
# train -  224   |   test -  55
#   Classifier  data_percentage  Testing_ACC  Testing Partition  Training Size  \
# 0  Auxiliary         0.003647    85.675164                  2            799
# 1  Auxiliary         0.003647    85.765246                  2            799
# 2  Auxiliary         0.001823    84.055490                  2            399
# 3  Auxiliary         0.001823    85.386902                  2            399
# 4  Auxiliary         0.002735    85.042789                  2            599
# 5  Auxiliary         0.002735    85.844519                  2            599
#
#   Learning Method
# 0        Combined
# 1        Combined
# 2        Combined
# 3        Combined
# 4        Combined
# 5        Combined

# %%
acc = []
classifier = []
data_fraction = []
learning_method = []
test_partition = []

for i in ['Auxiliary']:
    for j in df.data_percentage.unique():
        for p in df.partition_random_state.unique(): # random state of test partition
            for l in ['TCL (Conv)', 'TE2E (Conv)']:
                try:
                    trials = max_.loc[(i,j,p,l)] # fetch trials from max_
                except:
                    continue
                trial = get_test_acc_logit(df, trials.trial_id)

                # combined classfiers
                acc.append(trial['ACC'])
                classifier.append(i)
                data_fraction.append(j)
                learning_method.append(l)
                test_partition.append(p)
        
df_new = pd.DataFrame({'Classifier':classifier
                            , 'data_percentage':data_fraction
                            , 'Testing_ACC':acc,
                      'Learning Method':learning_method, 
                      'Testing Partition':test_partition})

df_new['Training Size'] = df_new['data_percentage'].apply(lambda x: int(T_SIZE * x))
df_new
# Out:
#    Classifier  data_percentage  Testing_ACC Learning Method  \
# 0   Auxiliary         0.003647    84.550941      TCL (Conv)
# 1   Auxiliary         0.003647    83.949196     TE2E (Conv)
# 2   Auxiliary         0.003647    85.511215      TCL (Conv)
# 3   Auxiliary         0.003647    82.853798     TE2E (Conv)
# 4   Auxiliary         0.003647    83.469955     TE2E (Conv)
# 5   Auxiliary         0.001823    83.606880      TCL (Conv)
# 6   Auxiliary         0.001823    83.178093     TE2E (Conv)
# 7   Auxiliary         0.001823    84.922081      TCL (Conv)
# 8   Auxiliary         0.001823    83.871727     TE2E (Conv)
# 9   Auxiliary         0.001823    83.925774     TE2E (Conv)
# 10  Auxiliary         0.002735    84.356369      TCL (Conv)
# 11  Auxiliary         0.002735    83.484375     TE2E (Conv)
# 12  Auxiliary         0.002735    85.767052      TCL (Conv)
# 13  Auxiliary         0.002735    84.682465     TE2E (Conv)
# 14  Auxiliary         0.002735    83.864517     TE2E (Conv)
#
#     Testing Partition  Training Size
# 0                   0            799
# 1                   0            799
# 2                   1            799
# 3                   1            799
# 4                   2            799
# 5                   0            399
# 6                   0            399
# 7                   1            399
# 8                   1            399
# 9                   2            399
# 10                  0            599
# 11                  0            599
# 12                  1            599
# 13                  1            599
# 14                  2            599

# %%
max_combined = df_new.merge(df_combined, on=list(df_combined), how='outer')
max_combined = max_combined.rename(columns={'Testing_ACC': 'Testing ACC'})
max_combined
# Out:
#    Classifier  data_percentage  Testing ACC Learning Method  \
# 0   Auxiliary         0.003647    84.550941      TCL (Conv)
# 1   Auxiliary         0.003647    83.949196     TE2E (Conv)
# 2   Auxiliary         0.003647    85.511215      TCL (Conv)
# 3   Auxiliary         0.003647    82.853798     TE2E (Conv)
# 4   Auxiliary         0.003647    83.469955     TE2E (Conv)
# 5   Auxiliary         0.001823    83.606880      TCL (Conv)
# 6   Auxiliary         0.001823    83.178093     TE2E (Conv)
# 7   Auxiliary         0.001823    84.922081      TCL (Conv)
# 8   Auxiliary         0.001823    83.871727     TE2E (Conv)
# 9   Auxiliary         0.001823    83.925774     TE2E (Conv)
# 10  Auxiliary         0.002735    84.356369      TCL (Conv)
# 11  Auxiliary         0.002735    83.484375     TE2E (Conv)
# 12  Auxiliary         0.002735    85.767052      TCL (Conv)
# 13  Auxiliary         0.002735    84.682465     TE2E (Conv)
# 14  Auxiliary         0.002735    83.864517     TE2E (Conv)
# 15  Auxiliary         0.003647    85.675164        Combined
# 16  Auxiliary         0.003647    85.765246        Combined
# 17  Auxiliary         0.001823    84.055490        Combined
# 18  Auxiliary         0.001823    85.386902        Combined
# 19  Auxiliary         0.002735    85.042789        Combined
# 20  Auxiliary         0.002735    85.844519        Combined
#
#     Testing Partition  Training Size
# 0                   0            799
# 1                   0            799
# 2                   1            799
# 3                   1            799
# 4                   2            799
# 5                   0            399
# 6                   0            399
# 7                   1            399
# 8                   1            399
# 9                   2            399
# 10                  0            599
# 11                  0            599
# 12                  1            599
# 13                  1            599
# 14                  2            599
# 15                  2            799
# 16                  2            799
# 17                  2            399
# 18                  2            399
# 19                  2            599
# 20                  2            599

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid", font_scale=1.5)
sns.color_palette("hls")

sns.catplot(data=max_combined, x='Training Size', y='Testing ACC'
            , hue='Learning Method',col='Classifier', kind='box',
           height=6, aspect=1.0,)
